# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
matplotlib.style.use('seaborn-notebook')
# %matplotlib inline

# %%
wp_df = pd.read_csv('fatal-police-shootings-data.csv', index_col=['id', 'armed'], parse_dates=['date'])

# %%
unarmed_df = wp_df.query('armed == "unarmed"')

# %%
unarmed_df
# Out:
#                                     name       date   manner_of_death   age  \
# id   armed
# 5    unarmed          John Paul Quintero 2015-01-03  shot and Tasered  23.0
# 16   unarmed               Autumn Steele 2015-01-06              shot  34.0
# 36   unarmed         Artago Damon Howard 2015-01-08              shot  36.0
# 352  unarmed          Joshua Omar Garcia 2015-01-26              shot  24.0
# 342  unarmed                Ralph Willis 2015-01-29              shot  42.0
# 114  unarmed               David Kassick 2015-02-02              shot  59.0
# 116  unarmed                 Jeremy Lett 2015-02-04              shot  28.0
# 125  unarmed           Joaquin Hernandez 2015-02-04              shot  28.0
# 138  unarmed     Antonio Zambrano-Montes 2015-02-10  shot and Tasered  35.0
# 147  unarmed              Richard Carlin 2015-02-13              shot  35.0
# 150  unarmed                 Lavall Hall 2015-02-15  shot and Tasered  25.0
# 159  unarmed             Michael Ireland 2015-02-17              shot  31.0
# 165  unarmed           Ruben Villalpando 2015-02-20              shot  31.0
# 371  unarmed                Daniel Elrod 2015-02-23  shot and Tasered  39.0
# 180  unarmed      Alexander Phillip Long 2015-02-26  shot and Tasered  31.0
# 183  unarmed                Rodney Biggs 2015-02-26              shot  49.0
# 185  unarmed  Ernesto Javiar Canepa Diaz 2015-02-27              shot  27.0
# 187  unarmed              Deven Guilford 2015-02-28  shot and Tasered  17.0
# 188  unarmed                Thomas Allen 2015-02-28              shot  34.0
# 194  unarmed      Charly Leundeu Keunang 2015-03-01  shot and Tasered  43.0
# 199  unarmed                Derek Cruice 2015-03-04              shot  26.0
# 201  unarmed      Sergio Alexander Navas 2015-03-05              shot  36.0
# 269  unarmed         Naeschylus  Vinzant 2015-03-06              shot  37.0
# 203  unarmed               Tony Robinson 2015-03-06              shot  19.0
# 205  unarmed                Anthony Hill 2015-03-09              shot  27.0
# 282  unarmed                 Bobby Gross 2015-03-12              shot  35.0
# 351  unarmed               Antonio Perez 2015-03-13              shot  32.0
# 292  unarmed                Roberto Leon 2015-03-17              shot  22.0
# 295  unarmed          Jamison  Childress 2015-03-19              shot  20.0
# 229  unarmed               Brandon Jones 2015-03-19              shot  18.0
# ...                                  ...        ...               ...   ...
# 1247 unarmed                David Joseph 2016-02-08              shot  17.0
# 1251 unarmed              Gustavo Najera 2016-02-09              shot  22.0
# 1270 unarmed             Calin Roquemore 2016-02-13              shot  24.0
# 1272 unarmed          Dyzhawn L. Perkins 2016-02-13              shot  19.0
# 1318 unarmed        Christopher J. Davis 2016-02-24              shot  21.0
# 1324 unarmed      Abraham Mitchell Fryer 2016-02-26              shot  35.0
# 1331 unarmed         Travis Boyd Bradley 2016-03-02              shot  36.0
# 1342 unarmed             Brandon Stanley 2016-03-04              shot  30.0
# 1333 unarmed                 James Scott 2016-03-06              shot  42.0
# 1357 unarmed                Peter Gaines 2016-03-12  shot and Tasered  37.0
# 1358 unarmed              Jose Raul Cruz 2016-03-13              shot  16.0
# 1359 unarmed                Joshua Grubb 2016-03-13              shot  30.0
# 1367 unarmed        Cristian Rene Medina 2016-03-16              shot  23.0
# 1438 unarmed                 Kevin Hicks 2016-04-05              shot  44.0
# 1456 unarmed                  Dion Daman 2016-04-12              shot  40.0
# 1463 unarmed              Jeff Robertson 2016-04-14  shot and Tasered  54.0
# 1466 unarmed            Eric John Wilson 2016-04-17              shot  22.0
# 1506 unarmed       Jeffrey Darrell Hobbs 2016-04-29              shot  48.0
# 1524 unarmed            Christian Bowman 2016-05-09              shot  23.0
# 1547 unarmed               Jeremias Cruz 2016-05-19              shot  30.0
# 1548 unarmed     Jessica Nelson-Williams 2016-05-19              shot  29.0
# 1553 unarmed                Travis Moore 2016-05-21              shot  38.0
# 1554 unarmed   Michael Eugene Wilson Jr. 2016-05-22              shot  27.0
# 1562 unarmed                Vernell Bing 2016-05-22              shot  22.0
# 1579 unarmed        Todd Brent Burroughs 2016-05-29  shot and Tasered  38.0
# 1596 unarmed               Andrew Henson 2016-06-07              shot  25.0
# 1637 unarmed             Antwun Shumpert 2016-06-18              shot  37.0
# 1647 unarmed        Deravis Caine Rogers 2016-06-22              shot  22.0
# 1653 unarmed                Dylan Nobles 2016-06-25              shot  19.0
# 1661 unarmed           Rodrigo Guardiola 2016-06-25  shot and Tasered  36.0
#
#              gender race              city state signs_of_mental_illness  \
# id   armed
# 5    unarmed      M    H           Wichita    KS                   False
# 16   unarmed      F    W        Burlington    IA                   False
# 36   unarmed      M    B            Strong    AR                   False
# 352  unarmed      M    H            Tahoka    TX                   False
# 342  unarmed      M    W        Stillwater    OK                   False
# 114  unarmed      M    W       Hummelstown    PA                   False
# 116  unarmed      M    B       Tallahassee    FL                   False
# 125  unarmed      M    H             Tempe    AZ                   False
# 138  unarmed      M    H             Pasco    WA                    True
# 147  unarmed      M    H           Reading    PA                   False
# 150  unarmed      M    B     Miami Gardens    FL                    True
# 159  unarmed      M    W       Springfield    MO                   False
# 165  unarmed      M    H            Euless    TX                   False
# 371  unarmed      M    W             Omaha    NE                   False
# 180  unarmed      M    W       Terre Haute    IN                   False
# 183  unarmed      M    W          Gulfport    MS                   False
# 185  unarmed      M    H         Santa Ana    CA                   False
# 187  unarmed      M    W   Roxand Township    MI                   False
# 188  unarmed      M    B          St Louis    MO                   False
# 194  unarmed      M    B       Los Angeles    CA                    True
# 199  unarmed      M    W           Deltona    FL                   False
# 201  unarmed      M    H           Burbank    CA                   False
# 269  unarmed      M    B            Aurora    CO                   False
# 203  unarmed      M    B           Madison    WI                   False
# 205  unarmed      M    B           Atlanta    GA                    True
# 282  unarmed      M    B        Washington    DC                    True
# 351  unarmed      M    H      Walnut Creek    CA                   False
# 292  unarmed      M    H        Sacramento    CA                   False
# 295  unarmed      M    W             Sumas    WA                    True
# 229  unarmed      M    B         Cleveland    OH                   False
# ...             ...  ...               ...   ...                     ...
# 1247 unarmed      M    B            Austin    TX                   False
# 1251 unarmed      M    H           Anaheim    CA                   False
# 1270 unarmed      M    B         Beckville    TX                   False
# 1272 unarmed      M    B           Arvonia    VA                   False
# 1318 unarmed      M    B         East Troy    WI                   False
# 1324 unarmed      M    W      Rapid Valley    SD                   False
# 1331 unarmed      M    W           Bel Air    MD                    True
# 1342 unarmed      M    W     East Berstadt    KY                   False
# 1333 unarmed      M    W          Bismarck    ND                   False
# 1357 unarmed      M    B           Houston    TX                   False
# 1358 unarmed      M    H           Addison    TX                   False
# 1359 unarmed      M    W       Lenoir City    TN                   False
# 1367 unarmed      M    H          Florence    CA                    True
# 1438 unarmed      M    B      Indianapolis    IN                   False
# 1456 unarmed      M    W            Denver    CO                   False
# 1463 unarmed      M    W         McPherson    KS                    True
# 1466 unarmed      M    W           El Paso    TX                    True
# 1506 unarmed      M    W           Jackson    MO                   False
# 1524 unarmed      M    W        St. Martin    MS                   False
# 1547 unarmed      M    H         Las Vegas    NV                   False
# 1548 unarmed      F    B     San Francisco    CA                   False
# 1553 unarmed      M    W       Oregon City    OR                    True
# 1554 unarmed      M    B  Hallandale Beach    FL                   False
# 1562 unarmed      M    B      Jacksonville    FL                   False
# 1579 unarmed      M    W        Stoneville    NC                   False
# 1596 unarmed      M    W           Wagoner    OK                   False
# 1637 unarmed      M    B            Tupelo    MS                   False
# 1647 unarmed      M    B           Atlanta    GA                   False
# 1653 unarmed      M    W            Fresno    CA                    True
# 1661 unarmed      M    H       Gainesville    GA                   False
#
#               threat_level         flee body_camera
# id   armed
# 5    unarmed         other  Not fleeing       False
# 16   unarmed         other  Not fleeing        True
# 36   unarmed        attack  Not fleeing       False
# 352  unarmed         other          Car       False
# 342  unarmed         other         Foot       False
# 114  unarmed         other         Foot       False
# 116  unarmed        attack  Not fleeing       False
# 125  unarmed         other  Not fleeing       False
# 138  unarmed         other         Foot       False
# 147  unarmed         other  Not fleeing       False
# 150  unarmed         other  Not fleeing       False
# 159  unarmed         other         Foot       False
# 165  unarmed         other  Not fleeing       False
# 371  unarmed         other  Not fleeing       False
# 180  unarmed         other  Not fleeing       False
# 183  unarmed         other  Not fleeing       False
# 185  unarmed  undetermined  Not fleeing       False
# 187  unarmed        attack  Not fleeing        True
# 188  unarmed         other          Car       False
# 194  unarmed        attack  Not fleeing        True
# 199  unarmed         other  Not fleeing       False
# 201  unarmed         other          Car       False
# 269  unarmed  undetermined         Foot       False
# 203  unarmed        attack         Foot       False
# 205  unarmed         other  Not fleeing       False
# 282  unarmed         other  Not fleeing       False
# 351  unarmed         other         Foot       False
# 292  unarmed  undetermined          Car       False
# 295  unarmed        attack  Not fleeing       False
# 229  unarmed        attack  Not fleeing       False
# ...                    ...          ...         ...
# 1247 unarmed         other  Not fleeing        True
# 1251 unarmed  undetermined  Not fleeing        True
# 1270 unarmed         other        Other       False
# 1272 unarmed        attack  Not fleeing       False
# 1318 unarmed  undetermined          Car       False
# 1324 unarmed        attack  Not fleeing       False
# 1331 unarmed         other  Not fleeing       False
# 1342 unarmed  undetermined  Not fleeing       False
# 1333 unarmed  undetermined         Foot       False
# 1357 unarmed         other         Foot       False
# 1358 unarmed  undetermined  Not fleeing       False
# 1359 unarmed         other          Car        True
# 1367 unarmed         other  Not fleeing       False
# 1438 unarmed        attack  Not fleeing        True
# 1456 unarmed         other          Car       False
# 1463 unarmed        attack  Not fleeing       False
# 1466 unarmed         other  Not fleeing       False
# 1506 unarmed        attack          Car       False
# 1524 unarmed         other  Not fleeing       False
# 1547 unarmed        attack  Not fleeing       False
# 1548 unarmed  undetermined          Car       False
# 1553 unarmed         other  Not fleeing       False
# 1554 unarmed         other          Car        True
# 1562 unarmed         other          Car       False
# 1579 unarmed         other          Car       False
# 1596 unarmed         other          Car        True
# 1637 unarmed        attack         Foot       False
# 1647 unarmed  undetermined        Other       False
# 1653 unarmed         other          Car        True
# 1661 unarmed         other        Other       False
#
# [128 rows x 12 columns]

# %%
plt.figure()
unarmed_df['race'].value_counts().plot(kind='bar', color=['brown','gray', 'green', 'yellow', 'blue'])
plt.axhline(0, color='K')
